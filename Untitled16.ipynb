# %% [markdown]
# <a href="https://colab.research.google.com/github/vyspriyL/adhoc-notes-daily-basis-/blob/master/Untitled16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %%
cv2.__version__
# Out:
# '3.4.3'

# %%
# image reading
img=cv2.imread("https://www.google.com/search?q=forest&rlz=1C1CHBD_enIN853IN853&tbm=isch&source=iu&ictx=1&fir=_0tNYTcBaCnsAM%253A%252ClWXel0K4gROJWM%252C_&vet=1&usg=AI4_-kTwdJshWyDdpGImd11Y0i3YeOEkIQ&sa=X&ved=2ahUKEwiO1OWKvo7jAhUMcCsKHZpwBu8Q9QEwAnoECAMQBg#imgrc=ixj5xG3u95HpoM:&vet=1")

# %%
img

# %%
print(img)
# Out:
# None

# %%
img=cv2.imread("mystical-by-nei-burnell-2.jpg")

# %%
print(img)
# Out:
# [[[94 93 72]
#   [79 78 57]
#   [82 81 60]
#   ...
#   [32 34 28]
#   [36 38 32]
#   [41 43 37]]
#
#  [[93 92 71]
#   [76 75 54]
#   [74 73 52]
#   ...
#   [43 45 39]
#   [44 46 40]
#   [44 46 40]]
#
#  [[88 87 66]
#   [80 79 58]
#   [75 74 53]
#   ...
#   [45 45 39]
#   [44 46 40]
#   [44 46 40]]
#
#  ...
#
#  [[19 28 25]
#   [18 27 24]
#   [33 39 38]
#   ...
#   [28 39 37]
#   [22 33 31]
#   [26 37 35]]
#
#  [[57 66 63]
#   [47 55 54]
#   [37 42 43]
#   ...
#   [32 43 41]
#   [27 38 36]
#   [27 38 36]]
#
#  [[37 45 44]
#   [59 67 66]
#   [59 64 65]
#   ...
#   [28 39 36]
#   [24 35 32]
#   [24 35 32]]]

# %%
img.shape
# Out:
# (533, 800, 3)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
# to display image
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=800x533 at 0x7F05407830F0>

# %%
# wait for window to close
#cv2.waitkey(0)  # milli micro second
#for infinity time
#cv2.waitKey(30)
